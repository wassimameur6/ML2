# %%
import pandas as pd
pd.options.display.max_columns=None
import numpy as np

# %%
df = pd.read_csv("../data/fraud.csv")
df.drop(['Unnamed: 0'],axis=1,inplace =True)
df.head()
# Out:
#   trans_date_trans_time            cc_num                            merchant  \
# 0   2019-01-01 00:00:18  2703186189652095          fraud_Rippin, Kub and Mann
# 1   2019-01-01 00:00:44      630423337322     fraud_Heller, Gutmann and Zieme
# 2   2019-01-01 00:00:51    38859492057661                fraud_Lind-Buckridge
# 3   2019-01-01 00:01:16  3534093764340240  fraud_Kutch, Hermiston and Farrell
# 4   2019-01-01 00:03:06   375534208663984                 fraud_Keeling-Crist
#
#         category     amt      first     last gender  \
# 0       misc_net    4.97   Jennifer    Banks      F
# 1    grocery_pos  107.23  Stephanie     Gill      F
# 2  entertainment  220.11     Edward  Sanchez      M
# 3  gas_transport   45.00     Jeremy    White      M
# 4       misc_pos   41.96      Tyler   Garcia      M
#
#                          street            city state    zip      lat  \
# 0                561 Perry Cove  Moravian Falls    NC  28654  36.0788
# 1  43039 Riley Greens Suite 393          Orient    WA  99160  48.8878
# 2      594 White Dale Suite 530      Malad City    ID  83252  42.1808
# 3   9443 Cynthia Court Apt. 038         Boulder    MT  59632  46.2306
# 4              408 Bradley Rest        Doe Hill    VA  24433  38.4207
#
#        long  city_pop                                job         dob  \
# 0  -81.1781      3495          Psychologist, counselling  1988-03-09
# 1 -118.2105       149  Special educational needs teacher  1978-06-21
# 2 -112.2620      4154        Nature conservation officer  1962-01-19
# 3 -112.1138      1939                    Patent attorney  1967-01-12
# 4  -79.4629        99     Dance movement psychotherapist  1986-03-28
#
#                           trans_num   unix_time  merch_lat  merch_long  \
# 0  0b242abb623afc578575680df30655b9  1325376018  36.011293  -82.048315
# 1  1f76529f8574734946361c461b024d99  1325376044  49.159047 -118.186462
# 2  a1a22d70485983eac12b5b88dad1cf95  1325376051  43.150704 -112.154481
# 3  6b849c168bdad6f867558c3793159a81  1325376076  47.034331 -112.561071
# 4  a41d7549acf90789359a9aa5346dcb46  1325376186  38.674999  -78.632459
#
#    is_fraud
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %% [markdown]
# ## full_suite for dataset

# %%
import deepchecks
deepchecks.__version__
# Out:
# '0.19.1'

# %%
from deepchecks.tabular.suites import full_suite
suites=full_suite()
suites
# Out:
# Full Suite: [
# 	0: TrainTestPerformance
# 		Conditions:
# 			0: Train-Test scores relative degradation is less than 0.1
# 	1: RocReport
# 		Conditions:
# 			0: AUC score for all the classes is greater than 0.7
# 	2: ConfusionMatrixReport
# 	3: PredictionDrift
# 		Conditions:
# 			0: Prediction drift score < 0.15
# 	4: SimpleModelComparison
# 		Conditions:
# 			0: Model performance gain over simple model is greater than 10%
# 	5: WeakSegmentsPerformance(n_to_show=5)
# 		Conditions:
# 			0: The relative performance of weakest segment is greater than 80% of average model performance.
# 	6: CalibrationScore
# 	7: RegressionErrorDistribution
# 		Conditions:
# 			0: Kurtosis value higher than -0.1
# 			1: Systematic error ratio lower than 0.01
# 	8: UnusedFeatures
# 		Conditions:
# 			0: Number of high variance unused features is less or equal to 5
# 	9: BoostingOverfit
# 		Conditions:
# 			0: Test score over iterations is less than 5% from the best score
# 	10: ModelInferenceTime
# 		Conditions:
# 			0: Average model inference time for one sample is less than 0.001
# 	11: DatasetsSizeComparison
# 		Conditions:
# 			0: Test-Train size ratio is greater than 0.01
# 	12: NewLabelTrainTest
# 		Conditions:
# 			0: Number of new label values is less or equal to 0
# 	13: NewCategoryTrainTest
# 		Conditions:
# 			0: Ratio of samples with a new category is less or equal to 0%
# 	14: StringMismatchComparison
# 		Conditions:
# 			0: No new variants allowed in test data
# 	15: DateTrainTestLeakageDuplicates
# 		Conditions:
# 			0: Date leakage ratio is less or equal to 0%
# 	16: DateTrainTestLeakageOverlap
# 		Conditions:
# 			0: Date leakage ratio is less or equal to 0%
# 	17: IndexTrainTestLeakage
# 		Conditions:
# 			0: Ratio of leaking indices is less or equal to 0%
# 	18: TrainTestSamplesMix(n_to_show=5)
# 		Conditions:
# 			0: Percentage of test data samples that appear in train data is less or equal to 5%
# 	19: FeatureLabelCorrelationChange(ppscore_params={}, random_state=42)
# 		Conditions:
# 			0: Train-Test features' Predictive Power Score difference is less than 0.2
# 			1: Train features' Predictive Power Score is less than 0.7
# 	20: FeatureDrift
# 		Conditions:
# 			0: categorical drift score < 0.2 and numerical drift score < 0.2
# 	21: LabelDrift
# 		Conditions:
# 			0: Label drift score < 0.15
# 	22: MultivariateDrift
# 		Conditions:
# 			0: Drift value is less than 0.25
# 	23: IsSingleValue
# 		Conditions:
# 			0: Does not contain only a single value
# 	24: SpecialCharacters
# 		Conditions:
# 			0: Ratio of samples containing solely special character is less or equal to 0.1%
# 	25: MixedNulls
# 		Conditions:
# 			0: Number of different null types is less or equal to 1
# 	26: MixedDataTypes
# 		Conditions:
# 			0: Rare data types in column are either more than 10% or less than 1% of the data
# 	27: StringMismatch
# 		Conditions:
# 			0: No string variants
# 	28: DataDuplicates
# 		Conditions:
# 			0: Duplicate data ratio is less or equal to 5%
# 	29: StringLengthOutOfBounds
# 		Conditions:
# 			0: Ratio of string length outliers is less or equal to 0%
# 	30: ConflictingLabels
# 		Conditions:
# 			0: Ambiguous sample ratio is less or equal to 0%
# 	31: OutlierSampleDetection
# 	32: FeatureLabelCorrelation(ppscore_params={}, random_state=42)
# 		Conditions:
# 			0: Features' Predictive Power Score is less than 0.8
# 	33: FeatureFeatureCorrelation
# 		Conditions:
# 			0: Not more than 0 pairs are correlated above 0.9
# 	34: IdentifierLabelCorrelation(ppscore_params={})
# 		Conditions:
# 			0: Identifier columns PPS is less or equal to 0
# ]

# %%
cat_features= df.select_dtypes(include=['object']).columns.tolist()
cat_features
# Out:
# ['trans_date_trans_time',
#  'merchant',
#  'category',
#  'first',
#  'last',
#  'gender',
#  'street',
#  'city',
#  'state',
#  'job',
#  'dob',
#  'trans_num']

# %%
from deepchecks.tabular import Dataset
dataframeTest=Dataset(df=df,label='is_fraud',cat_features=cat_features)
dataframeTest
# Out:
# <h4><b>Dataset Description</b></h4><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="min-width: 15px;"></th>
#       <th style="min-width: 15px;">Column</th>
#       <th style="min-width: 15px;">DType</th>
#       <th style="min-width: 15px;">Kind</th>
#       <th style="min-width: 15px;">Additional Info</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>is_fraud</td>
#       <td>integer</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>trans_date_trans_time</td>
#       <td>string</td>
#       <td>Categorical Feature</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>cc_num</td>
#       <td>integer</td>
#       <td>Numerical Feature</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>merchant</td>
#       <td>string</td>
#       <td>Categorical Feature</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>category</td>
#       <td>string</td>
#       <td>Categorical Feature</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>amt</td>
#       <td>floating</td>
#       <td>Numerical Feature</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>first</td>
#       <td>string</td>
#       <td>Categorical Feature</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>last</td>
#       <td>string</td>
#       <td>Categorical Feature</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>gender</td>
#       <td>string</td>
#       <td>Categorical Feature</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>street</td>
#       <td>string</td>
#       <td>Categorical Feature</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>city</td>
#       <td>string</td>
#       <td>Categorical Feature</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>state</td>
#       <td>string</td>
#       <td>Categorical Feature</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>zip</td>
#       <td>integer</td>
#       <td>Numerical Feature</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>lat</td>
#       <td>floating</td>
#       <td>Numerical Feature</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>long</td>
#       <td>floating</td>
#       <td>Numerical Feature</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>city_pop</td>
#       <td>integer</td>
#       <td>Numerical Feature</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>job</td>
#       <td>string</td>
#       <td>Categorical Feature</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>dob</td>
#       <td>string</td>
#       <td>Categorical Feature</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>trans_num</td>
#       <td>string</td>
#       <td>Categorical Feature</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>unix_time</td>
#       <td>integer</td>
#       <td>Numerical Feature</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>merch_lat</td>
#       <td>floating</td>
#       <td>Numerical Feature</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>merch_long</td>
#       <td>floating</td>
#       <td>Numerical Feature</td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# </div><h4><b>Dataset Content</b></h4><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="min-width: 15px;"></th>
#       <th style="min-width: 15px;">is_fraud</th>
#       <th style="min-width: 15px;">trans_date_trans_time</th>
#       <th style="min-width: 15px;">cc_num</th>
#       <th style="min-width: 15px;">merchant</th>
#       <th>...</th>
#       <th style="min-width: 15px;">trans_num</th>
#       <th style="min-width: 15px;">unix_time</th>
#       <th style="min-width: 15px;">merch_lat</th>
#       <th style="min-width: 15px;">merch_long</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>2019-01-01 00:00:18</td>
#       <td>2703186189652095</td>
#       <td>fraud_Rippin, Kub and Mann</td>
#       <td>...</td>
#       <td>0b242abb623afc578575680df30655b9</td>
#       <td>1325376018</td>
#       <td>36.011293</td>
#       <td>-82.048315</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>2019-01-01 00:00:44</td>
#       <td>630423337322</td>
#       <td>fraud_Heller, Gutmann and Zieme</td>
#       <td>...</td>
#       <td>1f76529f8574734946361c461b024d99</td>
#       <td>1325376044</td>
#       <td>49.159047</td>
#       <td>-118.186462</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0</td>
#       <td>2019-01-01 00:00:51</td>
#       <td>38859492057661</td>
#       <td>fraud_Lind-Buckridge</td>
#       <td>...</td>
#       <td>a1a22d70485983eac12b5b88dad1cf95</td>
#       <td>1325376051</td>
#       <td>43.150704</td>
#       <td>-112.154481</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0</td>
#       <td>2019-01-01 00:01:16</td>
#       <td>3534093764340240</td>
#       <td>fraud_Kutch, Hermiston and Farrell</td>
#       <td>...</td>
#       <td>6b849c168bdad6f867558c3793159a81</td>
#       <td>1325376076</td>
#       <td>47.034331</td>
#       <td>-112.561071</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0</td>
#       <td>2019-01-01 00:03:06</td>
#       <td>375534208663984</td>
#       <td>fraud_Keeling-Crist</td>
#       <td>...</td>
#       <td>a41d7549acf90789359a9aa5346dcb46</td>
#       <td>1325376186</td>
#       <td>38.674999</td>
#       <td>-78.632459</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>299995</th>
#       <td>0</td>
#       <td>2019-05-26 16:11:21</td>
#       <td>4482427013979020</td>
#       <td>fraud_Harris Group</td>
#       <td>...</td>
#       <td>3497cddb59d77dbad50973e62a644ab9</td>
#       <td>1338048681</td>
#       <td>39.298162</td>
#       <td>-82.030474</td>
#     </tr>
#     <tr>
#       <th>299996</th>
#       <td>0</td>
#       <td>2019-05-26 16:11:25</td>
#       <td>3506592072985012</td>
#       <td>fraud_Stiedemann Ltd</td>
#       <td>...</td>
#       <td>26d5d4e492cdaee820c9bd24c45852cf</td>
#       <td>1338048685</td>
#       <td>39.339959</td>
#       <td>-89.859340</td>
#     </tr>
#     <tr>
#       <th>299997</th>
#       <td>0</td>
#       <td>2019-05-26 16:11:57</td>
#       <td>581293083266</td>
#       <td>fraud_Torp, Muller and Borer</td>
#       <td>...</td>
#       <td>fada6acfb99187d9d3cd28fb10cf7017</td>
#       <td>1338048717</td>
#       <td>36.545200</td>
#       <td>-98.854027</td>
#     </tr>
#     <tr>
#       <th>299998</th>
#       <td>0</td>
#       <td>2019-05-26 16:12:03</td>
#       <td>30197398657930</td>
#       <td>fraud_Dare, Casper and Bartoletti</td>
#       <td>...</td>
#       <td>e2543ebcd97f0587b56baaddc261a535</td>
#       <td>1338048723</td>
#       <td>36.078714</td>
#       <td>-78.024839</td>
#     </tr>
#     <tr>
#       <th>299999</th>
#       <td>0</td>
#       <td>2019-05-26 16:12:26</td>
#       <td>6528911529051375</td>
#       <td>fraud_Emmerich-Rau</td>
#       <td>...</td>
#       <td>1204e9464e2871bcda67497ae211dd7a</td>
#       <td>1338048746</td>
#       <td>45.181078</td>
#       <td>-90.340056</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
suites.run(dataframeTest)
# Out:
#     <style>
#         progress {
#             -webkit-appearance: none;
#             border: none;
#             border-radius: 3px;
#             width: 300px;
#             height: 20px;
#             vertical-align: middle;
#             margin-right: 10px;
#             background-color: aliceblue;
#         }
#         progress::-webkit-progress-bar {
#             border-radius: 3px;
#             background-color: aliceblue;
#         }
#         progress::-webkit-progress-value {
#             background-color: #9d60fb;
#         }
#         progress::-moz-progress-bar {
#             background-color: #9d60fb;
#         }
#     </style>
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/abstracts/weak_segment_abstract.py:63: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Accordion(children=(VBox(children=(HTML(value='\n<h1 id="summary_QX6JM77ZTCNB3VWLE2LH94VO6">Full Suite</h1>\n<…

# %%
dfcopy=df.copy()
dfcopy.drop(['trans_date_trans_time','first', 'last', 'dob','trans_num','cc_num','unix_time','merchant', 'street', 'city','lat','long','state'] , axis=1, inplace=True)
#get categorical features
cat_features= dfcopy.select_dtypes(include=['object']).columns.tolist()
dataframeTest=Dataset(df=dfcopy,label='is_fraud',cat_features=cat_features)
dataframeTest
# Out:
# <h4><b>Dataset Description</b></h4><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="min-width: 15px;"></th>
#       <th style="min-width: 15px;">Column</th>
#       <th style="min-width: 15px;">DType</th>
#       <th style="min-width: 15px;">Kind</th>
#       <th style="min-width: 15px;">Additional Info</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>is_fraud</td>
#       <td>integer</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>category</td>
#       <td>string</td>
#       <td>Categorical Feature</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>amt</td>
#       <td>floating</td>
#       <td>Numerical Feature</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>gender</td>
#       <td>string</td>
#       <td>Categorical Feature</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>zip</td>
#       <td>integer</td>
#       <td>Numerical Feature</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>city_pop</td>
#       <td>integer</td>
#       <td>Numerical Feature</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>job</td>
#       <td>string</td>
#       <td>Categorical Feature</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>merch_lat</td>
#       <td>floating</td>
#       <td>Numerical Feature</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>merch_long</td>
#       <td>floating</td>
#       <td>Numerical Feature</td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# </div><h4><b>Dataset Content</b></h4><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="min-width: 15px;"></th>
#       <th style="min-width: 15px;">is_fraud</th>
#       <th style="min-width: 15px;">category</th>
#       <th style="min-width: 15px;">amt</th>
#       <th style="min-width: 15px;">gender</th>
#       <th>...</th>
#       <th style="min-width: 15px;">city_pop</th>
#       <th style="min-width: 15px;">job</th>
#       <th style="min-width: 15px;">merch_lat</th>
#       <th style="min-width: 15px;">merch_long</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>misc_net</td>
#       <td>4.97</td>
#       <td>F</td>
#       <td>...</td>
#       <td>3495</td>
#       <td>Psychologist, counselling</td>
#       <td>36.011293</td>
#       <td>-82.048315</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>grocery_pos</td>
#       <td>107.23</td>
#       <td>F</td>
#       <td>...</td>
#       <td>149</td>
#       <td>Special educational needs teacher</td>
#       <td>49.159047</td>
#       <td>-118.186462</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0</td>
#       <td>entertainment</td>
#       <td>220.11</td>
#       <td>M</td>
#       <td>...</td>
#       <td>4154</td>
#       <td>Nature conservation officer</td>
#       <td>43.150704</td>
#       <td>-112.154481</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0</td>
#       <td>gas_transport</td>
#       <td>45.00</td>
#       <td>M</td>
#       <td>...</td>
#       <td>1939</td>
#       <td>Patent attorney</td>
#       <td>47.034331</td>
#       <td>-112.561071</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0</td>
#       <td>misc_pos</td>
#       <td>41.96</td>
#       <td>M</td>
#       <td>...</td>
#       <td>99</td>
#       <td>Dance movement psychotherapist</td>
#       <td>38.674999</td>
#       <td>-78.632459</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>299995</th>
#       <td>0</td>
#       <td>food_dining</td>
#       <td>96.03</td>
#       <td>F</td>
#       <td>...</td>
#       <td>642</td>
#       <td>Building services engineer</td>
#       <td>39.298162</td>
#       <td>-82.030474</td>
#     </tr>
#     <tr>
#       <th>299996</th>
#       <td>0</td>
#       <td>food_dining</td>
#       <td>59.77</td>
#       <td>M</td>
#       <td>...</td>
#       <td>92608</td>
#       <td>Engineer, communications</td>
#       <td>39.339959</td>
#       <td>-89.859340</td>
#     </tr>
#     <tr>
#       <th>299997</th>
#       <td>0</td>
#       <td>health_fitness</td>
#       <td>77.82</td>
#       <td>M</td>
#       <td>...</td>
#       <td>1078</td>
#       <td>Podiatrist</td>
#       <td>36.545200</td>
#       <td>-98.854027</td>
#     </tr>
#     <tr>
#       <th>299998</th>
#       <td>0</td>
#       <td>kids_pets</td>
#       <td>53.20</td>
#       <td>F</td>
#       <td>...</td>
#       <td>12335</td>
#       <td>Chief Strategy Officer</td>
#       <td>36.078714</td>
#       <td>-78.024839</td>
#     </tr>
#     <tr>
#       <th>299999</th>
#       <td>0</td>
#       <td>personal_care</td>
#       <td>78.53</td>
#       <td>F</td>
#       <td>...</td>
#       <td>1478</td>
#       <td>Neurosurgeon</td>
#       <td>45.181078</td>
#       <td>-90.340056</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
suites.run(dataframeTest)
# Out:
#     <style>
#         progress {
#             -webkit-appearance: none;
#             border: none;
#             border-radius: 3px;
#             width: 300px;
#             height: 20px;
#             vertical-align: middle;
#             margin-right: 10px;
#             background-color: aliceblue;
#         }
#         progress::-webkit-progress-bar {
#             border-radius: 3px;
#             background-color: aliceblue;
#         }
#         progress::-webkit-progress-value {
#             background-color: #9d60fb;
#         }
#         progress::-moz-progress-bar {
#             background-color: #9d60fb;
#         }
#     </style>
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/abstracts/weak_segment_abstract.py:63: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Accordion(children=(VBox(children=(HTML(value='\n<h1 id="summary_EEVUH6SJ8CVFG811SAIXM90IM">Full Suite</h1>\n<…

# %% [markdown]
# ## Individual Test

# %%
from deepchecks.suites import data_integrity
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/suites.py:21: DeprecationWarning:
#
# Ability to import tabular suites from the `deepchecks.suites` is deprecated, please import from `deepchecks.tabular.suites` instead

# %%
integrity_test=data_integrity()
integrity_test
# Out:
# Data Integrity Suite: [
# 	0: IsSingleValue
# 		Conditions:
# 			0: Does not contain only a single value
# 	1: SpecialCharacters
# 		Conditions:
# 			0: Ratio of samples containing solely special character is less or equal to 0.1%
# 	2: MixedNulls
# 		Conditions:
# 			0: Number of different null types is less or equal to 1
# 	3: MixedDataTypes
# 		Conditions:
# 			0: Rare data types in column are either more than 10% or less than 1% of the data
# 	4: StringMismatch
# 		Conditions:
# 			0: No string variants
# 	5: DataDuplicates
# 		Conditions:
# 			0: Duplicate data ratio is less or equal to 5%
# 	6: StringLengthOutOfBounds
# 		Conditions:
# 			0: Ratio of string length outliers is less or equal to 0%
# 	7: ConflictingLabels
# 		Conditions:
# 			0: Ambiguous sample ratio is less or equal to 0%
# 	8: OutlierSampleDetection
# 	9: FeatureLabelCorrelation(ppscore_params={}, random_state=42)
# 		Conditions:
# 			0: Features' Predictive Power Score is less than 0.8
# 	10: FeatureFeatureCorrelation
# 		Conditions:
# 			0: Not more than 0 pairs are correlated above 0.9
# 	11: IdentifierLabelCorrelation(ppscore_params={})
# 		Conditions:
# 			0: Identifier columns PPS is less or equal to 0
# ]

# %%
result_integrity_test=integrity_test.run(dataframeTest)
result_integrity_test
# Out:
#     <style>
#         progress {
#             -webkit-appearance: none;
#             border: none;
#             border-radius: 3px;
#             width: 300px;
#             height: 20px;
#             vertical-align: middle;
#             margin-right: 10px;
#             background-color: aliceblue;
#         }
#         progress::-webkit-progress-bar {
#             border-radius: 3px;
#             background-color: aliceblue;
#         }
#         progress::-webkit-progress-value {
#             background-color: #9d60fb;
#         }
#         progress::-moz-progress-bar {
#             background-color: #9d60fb;
#         }
#     </style>
# Accordion(children=(VBox(children=(HTML(value='\n<h1 id="summary_84PTSYQQK64KPT39BHINVDJ5M">Data Integrity Sui…

# %% [markdown]
# ## Saving result as html file

# %%
htmlSave=result_integrity_test.save_as_html('result_integrity_test')

# %% [markdown]
# ## Data Distribution tests

# %%
from sklearn.model_selection import train_test_split
df_train,df_test=train_test_split(dfcopy,test_size=0.2)

# %%
print(f"df_train:{df_train.shape}")
print(f"df_test:{df_test.shape}")
# Out:
# df_train:(240000, 9)
# df_test:(60000, 9)

# %%
#transformation
ds_train=Dataset(df=df_train,label='is_fraud',cat_features=cat_features)
ds_test=Dataset(df=df_test,label='is_fraud',cat_features=cat_features)
data_distribution_test=suites.run(train_dataset=ds_train,test_dataset=ds_test)
data_distribution_test
# Out:
#     <style>
#         progress {
#             -webkit-appearance: none;
#             border: none;
#             border-radius: 3px;
#             width: 300px;
#             height: 20px;
#             vertical-align: middle;
#             margin-right: 10px;
#             background-color: aliceblue;
#         }
#         progress::-webkit-progress-bar {
#             border-radius: 3px;
#             background-color: aliceblue;
#         }
#         progress::-webkit-progress-value {
#             background-color: #9d60fb;
#         }
#         progress::-moz-progress-bar {
#             background-color: #9d60fb;
#         }
#     </style>
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/abstracts/weak_segment_abstract.py:63: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/abstracts/weak_segment_abstract.py:63: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/tabular/checks/train_test_validation/train_test_samples_mix.py:85: FutureWarning:
#
# DataFrame.applymap has been deprecated. Use DataFrame.map instead.
# Accordion(children=(VBox(children=(HTML(value='\n<h1 id="summary_O1WSG04FV407UTTZ5HN7ZR0X5">Full Suite</h1>\n<…

# %%
dataIntegrityHtmlSaved=data_distribution_test.save_as_html('data_distribution_test')

# %% [markdown]
# ## Model analysis and validation tests

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import  train_test_split

dfModel=df.copy()
dfModel.drop(['trans_date_trans_time','first', 'last', 'dob','trans_num','cc_num','unix_time','merchant', 'street', 'city','lat','long','state','job'] , axis=1, inplace=True)
dfModelCopy=dfModel.copy()
#get categorical features
cat_features= dfModel.select_dtypes(include=['object']).columns.tolist()
num_features= dfModel.select_dtypes(include=['integer']).columns.tolist()
num_features.remove("is_fraud")

# %%
#Only for gender
encode_dict = {  # Encoding dictionary
    'F': 0, 'M': 1}
dfModel['gender'] = dfModel['gender'].map(encode_dict)
dummy_cols = ['category']
#For other categorical columns
dfModel = pd.get_dummies(dfModel, columns=dummy_cols)
dfModel.head()
# Out:
#       amt  gender    zip  city_pop  merch_lat  merch_long  is_fraud  \
# 0    4.97       0  28654      3495  36.011293  -82.048315         0
# 1  107.23       0  99160       149  49.159047 -118.186462         0
# 2  220.11       1  83252      4154  43.150704 -112.154481         0
# 3   45.00       1  59632      1939  47.034331 -112.561071         0
# 4   41.96       1  24433        99  38.674999  -78.632459         0
#
#    category_entertainment  category_food_dining  category_gas_transport  \
# 0                   False                 False                   False
# 1                   False                 False                   False
# 2                    True                 False                   False
# 3                   False                 False                    True
# 4                   False                 False                   False
#
#    category_grocery_net  category_grocery_pos  category_health_fitness  \
# 0                 False                 False                    False
# 1                 False                  True                    False
# 2                 False                 False                    False
# 3                 False                 False                    False
# 4                 False                 False                    False
#
#    category_home  category_kids_pets  category_misc_net  category_misc_pos  \
# 0          False               False               True              False
# 1          False               False              False              False
# 2          False               False              False              False
# 3          False               False              False              False
# 4          False               False              False               True
#
#    category_personal_care  category_shopping_net  category_shopping_pos  \
# 0                   False                  False                  False
# 1                   False                  False                  False
# 2                   False                  False                  False
# 3                   False                  False                  False
# 4                   False                  False                  False
#
#    category_travel
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False

# %%
X = dfModel.drop('is_fraud', axis=1)  # Select features
y = dfModel['is_fraud']  # Target

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=1)  # Split data 80/20

# %%
# Normalize train & test features
scaler = MinMaxScaler()
X_train[num_features] = scaler.fit_transform(X_train[num_features])
X_test[num_features] = scaler.transform(X_test[num_features])

# %% [markdown]
# ## Smote

# %%
from imblearn.over_sampling import SMOTE

method= SMOTE()
x_resampled, y_resampled = method.fit_resample(X_train, y_train)

# %%
from sklearn.linear_model import LogisticRegression

model=LogisticRegression(solver='lbfgs' ,max_iter=10000)
model.fit(x_resampled,y_resampled)
# Out:
# LogisticRegression(max_iter=10000)

# %%
df_train,df_test=train_test_split(dfModel,test_size=0.2)
df_train_model=Dataset(df=df_train,label='is_fraud')
df_test_model=Dataset(df=df_test,label='is_fraud')
# Out:
# deepchecks - WARNING - It is recommended to initialize Dataset with categorical features by doing "Dataset(df, cat_features=categorical_list)". No categorical features were passed, therefore heuristically inferring categorical features in the data. 15 categorical features were inferred.: gender, category_entertainment, category_food_dining, category_gas_transport, category_grocery_net, category_grocery_pos, category_health_fitness... For full list use dataset.cat_features
# deepchecks - WARNING - It is recommended to initialize Dataset with categorical features by doing "Dataset(df, cat_features=categorical_list)". No categorical features were passed, therefore heuristically inferring categorical features in the data. 15 categorical features were inferred.: gender, category_entertainment, category_food_dining, category_gas_transport, category_grocery_net, category_grocery_pos, category_health_fitness... For full list use dataset.cat_features

# %%
result_model_test=suites.run(train_dataset=df_train_model,test_dataset=df_test_model,model=model)
# Out:
#     <style>
#         progress {
#             -webkit-appearance: none;
#             border: none;
#             border-radius: 3px;
#             width: 300px;
#             height: 20px;
#             vertical-align: middle;
#             margin-right: 10px;
#             background-color: aliceblue;
#         }
#         progress::-webkit-progress-bar {
#             border-radius: 3px;
#             background-color: aliceblue;
#         }
#         progress::-webkit-progress-value {
#             background-color: #9d60fb;
#         }
#         progress::-moz-progress-bar {
#             background-color: #9d60fb;
#         }
#     </style>
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/dataframes.py:47: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/dataframes.py:47: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/dataframes.py:47: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/dataframes.py:47: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/dataframes.py:47: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/dataframes.py:47: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/dataframes.py:47: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/dataframes.py:47: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/dataframes.py:47: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/dataframes.py:47: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/dataframes.py:47: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/dataframes.py:47: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/dataframes.py:47: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/dataframes.py:47: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/dataframes.py:47: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/abstracts/weak_segment_abstract.py:57: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Other' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/abstracts/weak_segment_abstract.py:57: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Other' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/abstracts/weak_segment_abstract.py:57: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Other' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/abstracts/weak_segment_abstract.py:57: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Other' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/abstracts/weak_segment_abstract.py:57: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Other' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/abstracts/weak_segment_abstract.py:57: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Other' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/abstracts/weak_segment_abstract.py:57: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Other' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/abstracts/weak_segment_abstract.py:57: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Other' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/abstracts/weak_segment_abstract.py:57: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Other' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/abstracts/weak_segment_abstract.py:57: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Other' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/abstracts/weak_segment_abstract.py:57: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Other' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/abstracts/weak_segment_abstract.py:57: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Other' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/abstracts/weak_segment_abstract.py:57: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Other' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/abstracts/weak_segment_abstract.py:57: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Other' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/abstracts/weak_segment_abstract.py:57: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Other' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/abstracts/weak_segment_abstract.py:63: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/abstracts/weak_segment_abstract.py:391: FutureWarning:
#
# ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/dataframes.py:47: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/dataframes.py:47: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/dataframes.py:47: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/dataframes.py:47: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/dataframes.py:47: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/dataframes.py:47: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/dataframes.py:47: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/dataframes.py:47: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/dataframes.py:47: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/dataframes.py:47: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/dataframes.py:47: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/dataframes.py:47: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/dataframes.py:47: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/dataframes.py:47: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/dataframes.py:47: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/abstracts/weak_segment_abstract.py:57: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Other' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/abstracts/weak_segment_abstract.py:57: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Other' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/abstracts/weak_segment_abstract.py:57: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Other' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/abstracts/weak_segment_abstract.py:57: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Other' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/abstracts/weak_segment_abstract.py:57: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Other' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/abstracts/weak_segment_abstract.py:57: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Other' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/abstracts/weak_segment_abstract.py:57: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Other' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/abstracts/weak_segment_abstract.py:57: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Other' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/abstracts/weak_segment_abstract.py:57: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Other' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/abstracts/weak_segment_abstract.py:57: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Other' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/abstracts/weak_segment_abstract.py:57: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Other' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/abstracts/weak_segment_abstract.py:57: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Other' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/abstracts/weak_segment_abstract.py:57: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Other' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/abstracts/weak_segment_abstract.py:57: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Other' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/abstracts/weak_segment_abstract.py:57: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Other' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/abstracts/weak_segment_abstract.py:63: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/utils/abstracts/weak_segment_abstract.py:391: FutureWarning:
#
# ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# /opt/anaconda3/lib/python3.12/site-packages/deepchecks/tabular/checks/train_test_validation/train_test_samples_mix.py:85: FutureWarning:
#
# DataFrame.applymap has been deprecated. Use DataFrame.map instead.

# %%
result_model_test
# Out:
# Accordion(children=(VBox(children=(HTML(value='\n<h1 id="summary_ZTTD15WACFCPF9LQJLT9KIWA6">Full Suite</h1>\n<…

# %%
html_result_model_test=result_model_test.save_as_html('result_model_test')
